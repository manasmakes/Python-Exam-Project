# %%
firstName = "Manas"         
lastName = "Sharma"          
age = 21                     
aadharNumber = "1234-5678-9012"  
height = 176.8               
weight = 84.0 
address = "(89_a,JAWAHAR COLONY,JHALAWAR)(115-PATEL CIRCLE,UDIAPUR)(49A,PADMAVTI COLONY-A, JAIPUR)"
country = "INDIA"
bloodGroup = "O+"
contactNo = "9876543210"
isprofessional = True    

# --- Display Output ---
print("AGENT FIRST NAME-",firstName)
print("AGENT LAST NAME-",lastName)
print("AGENT AGE-",age)
print("AGENT SOCIAL SECURITY NUMBER-",aadharNumber)
print ("AGENT HEIGHT-",height)
print ("AGENT WEIGHT-",weight)
print ("AGENT KNOWN RESIDENCE-",address)
print ("AGENT NATIONALITY-",country)
print ("AGENT BLOOD GROUP-",bloodGroup)
print ("AGENT KNOWN CONTACT NUMBER-",contactNo)
print ("AGENT DRIVING LICENSE STATUS-",isprofessional)
# Out:
# AGENT FIRST NAME- Manas
# AGENT LAST NAME- Sharma
# AGENT AGE- 21
# AGENT SOCIAL SECURITY NUMBER- 1234-5678-9012
# AGENT HEIGHT- 176.8
# AGENT WEIGHT- 84.0
# AGENT KNOWN RESIDENCE- (89_a,JAWAHAR COLONY,JHALAWAR)(115-PATEL CIRCLE,UDIAPUR)(49A,PADMAVTI COLONY-A, JAIPUR)
# AGENT NATIONALITY- INDIA
# AGENT BLOOD GROUP- O+
# AGENT KNOWN CONTACT NUMBER- 9876543210
# AGENT DRIVING LICENSE STATUS- True
